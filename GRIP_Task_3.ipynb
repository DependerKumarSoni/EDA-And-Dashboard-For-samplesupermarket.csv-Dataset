# %% [markdown]
# # This Notebook, *GRIP_Task_3.ipynb*, has been created as a part of **Graduate Rotational Internship Program (GRIP - Nov 2020)** organised by **The Sparks Foundation**.

# %% [markdown]
# ## **Task - 3: Exploratory Data Analysis - Retail**
# ### Q. Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’.
#
# ### Aim: To find weak areas which could be processed to make profit.

# %% [markdown]
# ### What is Exploratory Data Analysis?
# **EDA is a way for us to get an insight on the data mainly through data visualizations. Exploring data can be time consuming but\
# also a fun process. If you are interested in this, hop on and buckle up as we’re about to go for a ride in a data world!**

# %% [markdown]
# ### Author: **Depender Kumar Soni**
# **(Intern at The Sparks Foundation)**\
# **(GRIP - Nov 2020)**

# %%
import pandas as pd

# %% [markdown]
# ### Reading the data

# %%
# Here we are reading the data from csv file stored on our computer.
data = pd.read_csv("SampleSuperstore.csv")

# We can also read data from url as:
# data = pd.read_csv('https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view')

# %% [markdown]
# ### Printing initial five (head) and last five (tail) of data

# %%
# Let's look at the top five rows of data.
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Let's look at the last five rows of data.
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# Checking the shape of the data
shape = data.shape
print("There are " + str(shape[0]) + " rows and " + str(shape[1]) + " columns in our data.")
# Out:
# There are 9994 rows and 13 columns in our data.

# %%
# Let's have a quick look at statistical details of data.
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# Checking data types of data.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# Let's check no. of unique values for different features in data..!
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
data['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
data['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# From above results, it is clear that all these data belongs to a single country
# that is United States, and mentioning it again-and-again is useless, hence dropping
# the "country" column.

# %%
data.drop(['Country'], axis=1, inplace=True) # inplace=True deletes the column permanently.
data.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
data.shape
# Out:
# (9994, 12)

# %% [markdown]
# As we can see, shape method is now showing only two columns
# Also, there is no column named country in data frame.

# %% [markdown]
# ### Let's check for the missing values

# %%
data.isna().any()
# Out:
# Ship Mode       False
# Segment         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %% [markdown]
# As there is no missing data, we can proceed further.

# %% [markdown]
# ### Checking Data for duplicate elements

# %%
data.duplicated().sum()
# Out:
# 17

# %%
# Now Dropping the duplicate data
data.drop_duplicates()
# Out:
#            Ship Mode    Segment             City       State  Postal Code  \
# 0       Second Class   Consumer        Henderson    Kentucky        42420
# 1       Second Class   Consumer        Henderson    Kentucky        42420
# 2       Second Class  Corporate      Los Angeles  California        90036
# 3     Standard Class   Consumer  Fort Lauderdale     Florida        33311
# 4     Standard Class   Consumer  Fort Lauderdale     Florida        33311
# ...              ...        ...              ...         ...          ...
# 9989    Second Class   Consumer            Miami     Florida        33180
# 9990  Standard Class   Consumer       Costa Mesa  California        92627
# 9991  Standard Class   Consumer       Costa Mesa  California        92627
# 9992  Standard Class   Consumer       Costa Mesa  California        92627
# 9993    Second Class   Consumer      Westminster  California        92683
#
#      Region         Category Sub-Category     Sales  Quantity  Discount  \
# ...

# %% [markdown]
# ### Now we'll visualize relations between our data

# %%
# Let's print the correlation among data
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# plotting Correlations
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(data, diag_kws=dict(fill=False))
plt.show()

# %% [markdown]
# ### As per above graphs, Profit does not show any significant dependency over Postal Codes

# %%
# Dropping Postal Codes
col = ['Postal Code']
data_1 = data.drop(columns=col, axis=1)
data_1.columns
# Out:
# Index(['Ship Mode', 'Segment', 'City', 'State', 'Region', 'Category',
#        'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# We can see we have successfully removed 'Postal Code' from our dataframe.

# %% [markdown]
# ### Now Plotting the Heat Map for correlation among columns of new dataframe

# %%
# Plotting correlation heatmap
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(data_1.corr(), annot= True)
plt.show()

# %% [markdown]
# This correlation heatmap clearly tells that sales are highly correlated with Profit and well corellated by Quantity.
# Well, it is obvious that Quantity will increase with sales.
# The point to be noted is that, there is a negative correlation between discount & profit and discount & sales.

# %% [markdown]
# ### Now Plotting the Heat Map for convolution among columns of new dataframe

# %%
# Plotting convolution heatmap
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(data_1.cov(), annot= True)
plt.show()

# %% [markdown]
# ### Let's have a look at Sub-Category

# %%
# Plotting Sub-Categories Vs Sales
piv = pd.pivot_table(data_1, index='Sub-Category', values='Sales')
piv.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# Above graph represents the two most selling products are Copiers and Machines

# %% [markdown]
# ### Let's have a look at Profit associated with Sub-Categories

# %%
# Plotting Sub-Categories Vs Profit
piv = pd.pivot_table(data_1, index='Sub-Category', values='Profit')
piv.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# ### Checking the relationship between Sub-Category and Discount

# %%
# Plotting Sub-Categories Vs Discounts
piv = pd.pivot_table(data_1, index='Sub-Category', values='Discount')
piv.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# From above analysis it is clear that machines are second most selling product, still profit associated with machines is significantly low. And the table are the third best selling products but that is a loss making entity.
#
# Also, the second highest and the third highest discount is provided to machines and tables respectively.

# %% [markdown]
# ### Let's group our data around States

# %%
grp_by_State = data_1.groupby('Segment')['Category', 'State', 'Sales', 'Discount', 'Profit']
grp_by_State.head()
# Out:
# c:\users\xbee\tfvenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#            Category       State      Sales  Discount    Profit
# 0         Furniture    Kentucky   261.9600      0.00   41.9136
# 1         Furniture    Kentucky   731.9400      0.00  219.5820
# 2   Office Supplies  California    14.6200      0.00    6.8714
# 3         Furniture     Florida   957.5775      0.45 -383.0310
# 4   Office Supplies     Florida    22.3680      0.20    2.5164
# 5         Furniture  California    48.8600      0.00   14.1694
# 14  Office Supplies       Texas    68.8100      0.80 -123.8580
# 15  Office Supplies       Texas     2.5440      0.80   -3.8160
# 21  Office Supplies    Nebraska    19.4600      0.00    5.0596
# 22  Office Supplies    Nebraska    60.3400      0.00   15.6884
# ...

# %% [markdown]
# ### Let's check individual participation of states in profit

# %%
# Let's Plot no. of entries for different states
print(data_1['State'].value_counts())
plt.figure(figsize=(15,8))
sns.barplot(data=data_1, x='State', y='Profit', hue='Sub-Category')
plt.show()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %% [markdown]
# ### Now have a look at Segment and Region Columns

# %%
sns.barplot(data = data_1, x='Region', y='Profit', hue= 'Segment')
plt.show()

# %% [markdown]
# This barplot depicts that the central region has quite low number of concumers. Otherwise, overall distributaion is constant

# %% [markdown]
# ### We should also check Profit associated with different categories

# %%
sns.barplot(data = data_1, x='Region', y='Profit', hue= 'Category')
plt.show()

# %% [markdown]
# The barplot shows that the sale of furniture is significantly low in Central and Eastern Regions.\
# Also, there is very low office supply in Central Region.

# %% [markdown]
# ## As we looked above, there is some correlation among Profit, Quantity and Sales.
# ### Let's draw some line plots to understand

# %%
# Plotting lineplot between Profit and Quantity.
plt.figure(figsize = (10,4))
sns.lineplot('Quantity', 'Profit', data = data_1, color = 'g', label= 'Profit Vs Quantity')
plt.legend()
# Out:
# c:\users\xbee\tfvenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The graph shows a constant increment in Profit with increase in Quantity

# %%
# Plotting lineplot between Profit and Sales.
plt.figure(figsize = (10,4))
sns.lineplot('Sales', 'Profit', data = data_1, color = 'r', label= 'Profit Vs Sales')
plt.legend()
# Out:
# c:\users\xbee\tfvenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The graph shows a sudden downfall in profit after depicting a constant increment with increasing sales

# %%
# Plotting lineplot between Profit and Discount.
plt.figure(figsize = (10,4))
sns.lineplot('Discount', 'Profit', data = data_1, color = 'b', label= 'Profit Vs Discount')
plt.legend()
# Out:
# c:\users\xbee\tfvenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Conclusion
#
# One thing to be noted is that while the superstore is incurring losses due to giving discounts on its products, they can't stop giving discounts of their products. Most of the heavy discounts are during festivals, end-of-season and clearance sales which are necessary so that the store can make space in their warehouses for fresh stock. Also, by incurring small losses, the company gains in the future by attracting more long term customers. Therefore, the small losses from discounts are an essential part of company's business

# %% [markdown]
# # The Dashboard!

# %%
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output


# Load Data
df = data_1

statelist = df['State'].unique()
statelist.sort()

# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("Dashboard for Performing EDA on samplesuperstore.csv dataset"),
    dcc.Graph(id='graph'),
    html.Label([
        "State",
        dcc.Dropdown(
            id='state-dropdown', clearable=False,
            value='Alabama', options=[
                {'label': c, 'value': c}
                for c in statelist
            ])
    ]),
])


# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    [Input("state-dropdown", "value")]
)

def update_figure(state):
    filtered_df = df[df['State'] == state]

    fig = px.bar(filtered_df, x='City', y='Profit')

    return fig


if __name__ == '__main__':
    app.run_server(mode='inline')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Thankyou
